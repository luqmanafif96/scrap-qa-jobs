# %%
import pandas as pd
import os

# %% [markdown]
# #### Write the path to fetch data

# %%
path = "./data"
files = [file for file in os.listdir(path) if not file.startswith('.')]

all_fill_data = pd.DataFrame()

for file in files:
    current_data = pd.read_csv(path+"/"+file)
    all_fill_data = pd.concat([all_fill_data, current_data])
    
all_fill_data.to_csv("all_jira_copy.csv", index=False)

# %%
all_data = pd.read_csv("all_jira_copy.csv")
all_data.head()
# display(all_data.head())
# Out:
#                                              Summary   Issue key  Issue id  \
# 0                    [Admin Tool] Deal : create copy  FAVE-13640     44689
# 1  [Admin tool] Partner level category : DLD & Fa...  FAVE-13657     44706
# 2      [Admin tool ] Deal & sponsor voucher category  FAVE-13662     44712
# 3             Backed: Singapore : ISETAN (Singapore)  FAVE-12469     43200
# 4                       Backed: Singapore : Kiztopia  FAVE-12468     43199
#
#    Parent id Issue Type  Status Project key Project name Project type  \
# 0        NaN        Bug  Closed        FAVE         Fave     software
# 1    44689.0   Sub-task  Closed        FAVE         Fave     software
# 2    44689.0   Sub-task  Closed        FAVE         Fave     software
# 3        NaN      Story  Closed        FAVE         Fave     software
# 4        NaN      Story  Closed        FAVE         Fave     software
#
#          Project lead  ... Comment.3  Comment.4  Comment.5 Comment.6  \
# ...
